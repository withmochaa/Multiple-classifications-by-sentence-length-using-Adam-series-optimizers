# %%
import pandas as pd

data_row_일반질문=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0426/row/normal data/row/콜센터민원_일반 행정 문의_상담사질문.csv",index_col=0)
data_row_일반답변=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0426/row/normal data/row/콜센터민원_일반 행정 문의_상담사답변.csv",index_col=0)
data_row_피싱금융형=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0426/row/fishing data/row data/대출사기형.csv",index_col=0)
data_row_기관사칭형=pd.read_csv("/Users/withmocha/Desktop/DATA/Capston Design(2024)/data(sentence)/0426/row/fishing data/row data/수사기관사칭형.csv",index_col=0)

# %%
data_row_일반질문
# Out:
#                                 상담사질문(요청)
# 0                       어떤 은행을 이용하고 계십니까?
# 1                         어느지점으로 안내해드릴까요?
# 2                 지금 전화거신 핸드폰이 본인명의 맞습니까?
# 3                        생년월일을 말씀해주시겠습니까?
# 4                         살고계신 주소는 어디입니까?
# ...                                   ...
# 4492                      서울시에서 진행하는 건가요?
# 4493                         어떠점이 궁금하십니까?
# 4494  공연, 체험, 전시, 기타 등이 있는데 어느걸로 안내해드릴까요?
# 4495             네. 혼인신고의 어떤 내용을 알고싶으신가요?
# 4496                  서울에 위치한거 말씀하시는 건가요?
#
# [4497 rows x 1 columns]

# %%
data_row_일반답변
# Out:
#                                                 상담사답변
# 0                      이용하시는 은행의 사이트에서 지방세 납부가 가능합니다.
# 1                 그럼 스마트폰에서 기업은행 어플을 설치하시면 납부가 가능합니다.
# 2                                        방문납부도 가능합니다.
# 3                             도보로 10분위치에 서울역지점이 있습니다.
# 4                                 도보로 가시는게 빠를 것 같습니다.
# ...                                               ...
# 20065                                     62400원 입니다.
# 20066                                   1423200원 입니다.
# 20067  입주신청서와 추천서, 급여내역서 외 기타 서류를 갖고 홈페이지에서 신청하면 됩니다.
# 20068                                    1~3순위가 있습니다.
# 20069             국가유공자 자녀 및 국민기초생활수급권자를 1순위로 두고있습니다.
#
# [20070 rows x 1 columns]

# %%
data_row_기관사칭형
# Out:
#                                                    내용
# 0   ['아 서울 중앙 지검 첨단 범죄 수사 일부 이희나 수사관입니다.', '본 사건 조...
# 1   ['여보세요', '여보세요 OOO씨 혹시 맞습니까?', '네', '저는 서울 중앙 ...
# 2   ['여보세요', '네', '네 안녕하십니까.', '혹시 OOO 핸드폰 맞으십니까?'...
# 3   ['수고하십니다.', '여기는 서울 중앙 지검이고요', '네', '저는 1,000만...
# 4   ['어 이름은 김호철이고 태어난 곳은 전라도 광주, 올해로 사십세된 남성에 농협 은...
# 5   ['네 여보세요', '네 네', '아 아 다른 게 아니라 그 OOO 본인 관련된 명...
# 6   ['어 제가 한가지만 좀 여쭤볼게요.', '혹시 문은정이라는 사람 들어 보시거나 알...
# 7   ['본인께서도 인지를 못하시는 거 확인을 좀 부탁드릴게요.', '본인 혹시 중고나라...
# 8   ['증거를 속이게 되면 어 증거 자료로 솔직히 어려운 부분이 조금 있으신데 혹시 지...
# 9   ['사기범로 보는 건 아니고요.', '저희가 어느 정도 개인 명의 도용에 따른 피해...
# 10  ['말씀 하세요', '업무 보셨나요?', '그냥 해지하신 시간 말씀해주시겠어요.',...
# 11  ['예 아 그러니까 김명식 이란 사람이 제 주민 번호랑', '네 네 아 통장 개설해...
# 12  ['사기범:1 5882 114예 전화하셔서요.', '저도 대출 좀직장 인신용 대출 ...
# 13  ['여보세요', '네 여보세요.', '네 계좌이체 했어요.', '얼마 하셨죠?', ...
# 14  ['네 여보세요', '네 네', '저 근데요', '지금 와서 이러는 것도 웃기지만....
# 15  ['그러니까 제 통장이 실물 통장이 있었다고요?', '네 국민하고 신한 은행 통장 ...
# ...

# %%
data_row_피싱금융형
# Out:
#                                                    내용
# 0   ['여보세요', '네   님', '예 예', '어저께 통화했던 최영환입니다', '아...
# 1   ['여보세요', '안녕하세요', '고객님 김종현 대리입니다', '아네 대리님', '...
# 2   ['네 여보세요?', '여보세요', '네 ㅇㅇ 맞으신가요?', '네네', '네 안녕...
# 3   ['네', '네 여보세요', '뭐 어디세요?', '아 네 안녕하세요', '저희 그 ...
# 4   ['여보세요', '네   님', '예 예', '어저께 통화했던 최영환입니다', '아...
# ..                                                ...
# 71  ['네', '네 여보세요', '뭐 어디세요?', '아 네 안녕하세요', '저희 그 ...
# 72  ['여보세요', '네   님', '예 예', '어저께 통화했던 최영환입니다', '아...
# 73  ['여보세요', '안녕하세요', '고객님 김종현 대리입니다', '아네 대리님', '...
# 74  ['네 여보세요?', '여보세요', '네 ㅇㅇ 맞으신가요?', '네네', '네 안녕...
# 75  ['네', '네 여보세요', '뭐 어디세요?', '아 네 안녕하세요', '저희 그 ...
#
# [76 rows x 1 columns]

# %%
data_row_일반답변[:40]
# Out:
#                                                 상담사답변
# 0                      이용하시는 은행의 사이트에서 지방세 납부가 가능합니다.
# 1                 그럼 스마트폰에서 기업은행 어플을 설치하시면 납부가 가능합니다.
# 2                                        방문납부도 가능합니다.
# 3                             도보로 10분위치에 서울역지점이 있습니다.
# 4                                 도보로 가시는게 빠를 것 같습니다.
# 5                               위택스 사이트에서 납부하실수 있습니다.
# 6                                www.wetax.go.kr 입니다.
# 7                     이용하시는 은행의 사이트에서도 지방세 납부가 가능합니다.
# 8                               간단한 본인확인 후 안내해드리겠습니다.
# 9                                        본인확인이 되셨습니다.
# 10                                 지방세는 22만원으로 조회됩니다.
# 11                       온라인으로는 위택스나 은행 홈페이지에서 가능합니다.
# 12                                OOOO.OOO.go.kr 입니다.
# 13                                   현재로썬 진행될 예정입니다.
# 14                          네, 철저한 방역수칙하에 진행할 예정입니다.
# 15                            예매사이트 통해서 환불하실 수 있습니다.
# ...

# %%
data_row_일반답변.iloc[31,0]
# Out:
# '네 감사합니다.'

# %%
print(len(data_row_일반답변.iloc[31,0]))
# Out:
# 8

# %%
count=0
for i in range(data_row_일반질문.shape[0]):
    if len(data_row_일반질문.iloc[i,0])>len(data_row_일반답변.iloc[31,0]):
        count=count+1

# %%
for j in range(0,data_row_일반답변.shape[0]):
    if len(data_row_일반답변.iloc[j,0])>len(data_row_일반답변.iloc[31,0]):
        count=count+1

# %%
count
# Out:
# 22589

# %%
data_row_normal=pd.DataFrame(index=range(count),columns=['sentence'])

# %%
data_row_normal
# Out:
#       sentence
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ...        ...
# 22584      NaN
# 22585      NaN
# 22586      NaN
# 22587      NaN
# 22588      NaN
#
# [22589 rows x 1 columns]

# %%
count=0
for i in range(data_row_일반질문.shape[0]):
    if len(data_row_일반질문.iloc[i,0])>len(data_row_일반답변.iloc[31,0]):
        data_row_normal.iloc[i,0]=data_row_일반질문.iloc[i,0]
        count=count+1

# %%
for i in range(data_row_일반답변.shape[0]):
    if len(data_row_일반답변.iloc[i,0])>len(data_row_일반답변.iloc[31,0]):
        data_row_normal.iloc[count,0]=data_row_일반답변.iloc[i,0]
        count=count+1

# %%
data_row_normal
# Out:
#                                              sentence
# 0                                   어떤 은행을 이용하고 계십니까?
# 1                                     어느지점으로 안내해드릴까요?
# 2                             지금 전화거신 핸드폰이 본인명의 맞습니까?
# 3                                    생년월일을 말씀해주시겠습니까?
# 4                                     살고계신 주소는 어디입니까?
# ...                                               ...
# 22584                                     62400원 입니다.
# 22585                                   1423200원 입니다.
# 22586  입주신청서와 추천서, 급여내역서 외 기타 서류를 갖고 홈페이지에서 신청하면 됩니다.
# 22587                                    1~3순위가 있습니다.
# 22588             국가유공자 자녀 및 국민기초생활수급권자를 1순위로 두고있습니다.
#
# [22589 rows x 1 columns]

# %%
y=pd.DataFrame(index=range(data_row_normal.shape[0]),columns=['predict'])

# %%
y=y.fillna('0')

# %%
data_normal=pd.concat([data_row_normal,y],axis=1)

# %%
data_normal
# Out:
#                                              sentence predict
# 0                                   어떤 은행을 이용하고 계십니까?       0
# 1                                     어느지점으로 안내해드릴까요?       0
# 2                             지금 전화거신 핸드폰이 본인명의 맞습니까?       0
# 3                                    생년월일을 말씀해주시겠습니까?       0
# 4                                     살고계신 주소는 어디입니까?       0
# ...                                               ...     ...
# 22584                                     62400원 입니다.       0
# 22585                                   1423200원 입니다.       0
# 22586  입주신청서와 추천서, 급여내역서 외 기타 서류를 갖고 홈페이지에서 신청하면 됩니다.       0
# 22587                                    1~3순위가 있습니다.       0
# 22588             국가유공자 자녀 및 국민기초생활수급권자를 1순위로 두고있습니다.       0
#
# [22589 rows x 2 columns]
